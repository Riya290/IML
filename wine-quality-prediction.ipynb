# %% [markdown]
# # Wine Quality measurement

# %%
# importing important libraries for model

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Read CSV File
df = pd.read_csv('/kaggle/input/wine-quality-dataset/WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
# Print First Five Rows
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
# Print Last Five Rows 
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
# Check Data is null or not
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
# Print Columns Name
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
# Print Shape
df.shape
# Out:
# (1143, 13)

# %%
# Print Information
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]>

# %%
# Description of dataset.
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
y_train = df['quality'].values
x_train = df.drop(columns = ['quality']).values

# %%
print("Data type of X_train:", x_train.dtype)
print("Data type of y_train:", y_train.dtype)
# Out:
# Data type of X_train: float64
# Data type of y_train: int64

# %%
# Data visulation
# plotting each features against the output variable y
y_train = y_train.reshape(-1)

# list of feature names
features = ["fixed acidity", "volatile acidity", "citric acid", "resid+D26", "chlorides", "free sulfur dioxide", "density", "pH", "sulphates","alcohol", "Id"]

# Create subplots
fig, axes = plt.subplots(3, 4, figsize=(20, 15))

# Plot each feature against the binary target
for k in range(11):  # We only have 8 subplots, adjust as necessary
    i = k // 4  # Row index
    j = k % 4   # Column index
    axes[i, j].scatter(x_train[:, k], y_train, c=y_train, cmap='bwr', alpha=0.75, edgecolor='k')
    axes[i, j].set_title(f'{features[k]} vs. Target Value')
    axes[i, j].set_xlabel(f'Feature {k+1}')
    axes[i, j].set_ylabel('Target value')
# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.25, random_state = 2)

# %%
# view the training variable
print("Elements in X_train are:\n", x_train[:13])
print("Type of X_train:",type(x_train))

print("\n Elements in y_train are:\n", y_train[:13])
print("Type of y_train:",type(y_train))
# Out:
# Elements in X_train are:
#  [[6.7000e+00 5.4000e-01 1.3000e-01 2.0000e+00 7.6000e-02 1.5000e+01
#   3.6000e+01 9.9730e-01 3.6100e+00 6.4000e-01 9.8000e+00 8.2300e+02]
#  [7.9000e+00 5.4500e-01 6.0000e-02 4.0000e+00 8.7000e-02 2.7000e+01
#   6.1000e+01 9.9650e-01 3.3600e+00 6.7000e-01 1.0700e+01 2.7500e+02]
#  [1.1500e+01 4.1000e-01 5.2000e-01 3.0000e+00 8.0000e-02 2.9000e+01
#   5.5000e+01 1.0001e+00 3.2600e+00 8.8000e-01 1.1000e+01 3.5600e+02]
#  [9.3000e+00 5.0000e-01 3.6000e-01 1.8000e+00 8.4000e-02 6.0000e+00
#   1.7000e+01 9.9704e-01 3.2700e+00 7.7000e-01 1.0800e+01 1.0490e+03]
#  [8.3000e+00 6.5000e-01 1.0000e-01 2.9000e+00 8.9000e-02 1.7000e+01
#   4.0000e+01 9.9803e-01 3.2900e+00 5.5000e-01 9.5000e+00 7.5000e+02]
#  [7.2000e+00 1.0000e+00 0.0000e+00 3.0000e+00 1.0200e-01 7.0000e+00
#   1.6000e+01 9.9586e-01 3.4300e+00 4.6000e-01 1.0000e+01 7.7500e+02]
#  [9.9000e+00 7.4000e-01 2.8000e-01 2.6000e+00 7.8000e-02 2.1000e+01
#   7.7000e+01 9.9800e-01 3.2800e+00 5.1000e-01 9.8000e+00 7.1400e+02]
#  [9.3000e+00 3.3000e-01 4.5000e-01 1.5000e+00 5.7000e-02 1.9000e+01
#   3.7000e+01 9.9498e-01 3.1800e+00 8.9000e-01 1.1100e+01 1.0700e+03]
#  [1.0300e+01 5.0000e-01 4.2000e-01 2.0000e+00 6.9000e-02 2.1000e+01
#   5.1000e+01 9.9820e-01 3.1600e+00 7.2000e-01 1.1500e+01 4.6600e+02]
#  [1.0100e+01 3.1000e-01 3.5000e-01 1.6000e+00 7.5000e-02 9.0000e+00
#   2.8000e+01 9.9672e-01 3.2400e+00 8.3000e-01 1.1200e+01 8.3800e+02]
#  [1.1300e+01 3.6000e-01 6.6000e-01 2.4000e+00 1.2300e-01 3.0000e+00
#   8.0000e+00 9.9642e-01 3.2000e+00 5.3000e-01 1.1900e+01 1.0210e+03]
#  [9.2000e+00 5.9000e-01 2.4000e-01 3.3000e+00 1.0100e-01 2.0000e+01
#   4.7000e+01 9.9880e-01 3.2600e+00 6.7000e-01 9.6000e+00 5.4000e+02]
#  [7.1000e+00 8.7500e-01 5.0000e-02 5.7000e+00 8.2000e-02 3.0000e+00
#   1.4000e+01 9.9808e-01 3.4000e+00 5.2000e-01 1.0200e+01 1.4780e+03]]
# Type of X_train: <class 'numpy.ndarray'>
#
#  Elements in y_train are:
#  [5 6 5 6 5 5 5 7 6 7 6 5 3]
# Type of y_train: <class 'numpy.ndarray'>

# %%
# view the training variable
print("Elements in X_train are:\n", x_test[:13])
print("Type of X_train:",type(x_test))

print("\n Elements in y_train are:\n", y_test[:13])
print("Type of y_train:",type(y_test))
# Out:
# Elements in X_train are:
#  [[9.8000e+00 3.9000e-01 4.3000e-01 1.6500e+00 6.8000e-02 5.0000e+00
#   1.1000e+01 9.9478e-01 3.1900e+00 4.6000e-01 1.1400e+01 1.1810e+03]
#  [7.4000e+00 3.6000e-01 2.9000e-01 2.6000e+00 8.7000e-02 2.6000e+01
#   7.2000e+01 9.9645e-01 3.3900e+00 6.8000e-01 1.1000e+01 3.1400e+02]
#  [1.1400e+01 2.6000e-01 4.4000e-01 3.6000e+00 7.1000e-02 6.0000e+00
#   1.9000e+01 9.9860e-01 3.1200e+00 8.2000e-01 9.3000e+00 2.8000e+02]
#  [6.8000e+00 6.1000e-01 4.0000e-02 1.5000e+00 5.7000e-02 5.0000e+00
#   1.0000e+01 9.9525e-01 3.4200e+00 6.0000e-01 9.5000e+00 2.2200e+02]
#  [6.7000e+00 2.8000e-01 2.8000e-01 2.4000e+00 1.2000e-02 3.6000e+01
#   1.0000e+02 9.9064e-01 3.2600e+00 3.9000e-01 1.1700e+01 8.3600e+02]
#  [7.6000e+00 3.6000e-01 3.1000e-01 1.7000e+00 7.9000e-02 2.6000e+01
#   6.5000e+01 9.9716e-01 3.4600e+00 6.2000e-01 9.5000e+00 1.1730e+03]
#  [7.8000e+00 7.0000e-01 6.0000e-02 1.9000e+00 7.9000e-02 2.0000e+01
#   3.5000e+01 9.9628e-01 3.4000e+00 6.9000e-01 1.0900e+01 1.2540e+03]
#  [7.6000e+00 9.0000e-01 6.0000e-02 2.5000e+00 7.9000e-02 5.0000e+00
#   1.0000e+01 9.9670e-01 3.3900e+00 5.6000e-01 9.8000e+00 9.8000e+01]
#  [1.1300e+01 6.2000e-01 6.7000e-01 5.2000e+00 8.6000e-02 6.0000e+00
#   1.9000e+01 9.9880e-01 3.2200e+00 6.9000e-01 1.3400e+01 4.5500e+02]
#  [7.9000e+00 5.7000e-01 3.1000e-01 2.0000e+00 7.9000e-02 1.0000e+01
#   7.9000e+01 9.9677e-01 3.2900e+00 6.9000e-01 9.5000e+00 1.2160e+03]
#  [7.7000e+00 5.4000e-01 2.6000e-01 1.9000e+00 8.9000e-02 2.3000e+01
#   1.4700e+02 9.9636e-01 3.2600e+00 5.9000e-01 9.7000e+00 1.4930e+03]
#  [8.7000e+00 8.4000e-01 0.0000e+00 1.4000e+00 6.5000e-02 2.4000e+01
#   3.3000e+01 9.9540e-01 3.2700e+00 5.5000e-01 9.7000e+00 6.3500e+02]
#  [9.6000e+00 8.8000e-01 2.8000e-01 2.4000e+00 8.6000e-02 3.0000e+01
#   1.4700e+02 9.9790e-01 3.2400e+00 5.3000e-01 9.4000e+00 6.3600e+02]]
# Type of X_train: <class 'numpy.ndarray'>
#
#  Elements in y_train are:
#  [5 5 6 5 7 6 5 5 8 6 5 5 5]
# Type of y_train: <class 'numpy.ndarray'>

# %%
# Check the dimensions of testing variables
print ('The shape of X_test is: ' + str(x_test.shape))
print ('The shape of y_test is: ' + str(y_test.shape))
print ('We have m = %d testing examples' % (len(y_test)))
# Out:
# The shape of X_test is: (286, 12)
# The shape of y_test is: (286,)
# We have m = 286 testing examples

# %%
from sklearn.linear_model import LinearRegression # Import Linerar Regression model

model = LinearRegression()

# X_train_new = X_train_new.reshape(-1, 1)
model.fit(x_train, y_train)

m = x_train.shape[0]
predicted = np.zeros(m)

# predicted = model.predict(X_test)

print("coef :",model.coef_)
print("intercept :",model.intercept_)
# Out:
# coef : [ 1.80751366e-02 -1.09539108e+00 -2.49016831e-01 -1.52307207e-02
#  -1.75597121e+00  6.42035111e-03 -4.10601978e-03  2.07768211e+00
#  -4.58411619e-01  7.67279803e-01  2.94483724e-01 -5.31782584e-05]
# intercept : 2.333271551098872

# %%
from sklearn.metrics import mean_squared_error

predicted = model.predict(x_train)

# Calculate metrics
mse = mean_squared_error(y_train, predicted)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Root mean Squared Error: {rmse}")
# Out:
# Mean Squared Error: 0.4113998493149198
# Root mean Squared Error: 0.641404590968072

# %%
predicted = model.predict(x_test)

# Calculate metrics
mse = mean_squared_error(y_test, predicted)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse}")
print(f"Root mean Squared Error: {rmse}")
# Out:
# Mean Squared Error: 0.40150310423242525
# Root mean Squared Error: 0.6336427260155563
